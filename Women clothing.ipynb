# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Sruti\Downloads\women_clothing_ecommerce_sales - women_clothing_ecommerce_sales.csv")
df
# Out:
#      order_id          order_date   sku      color      size  unit_price  \
# 0           1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1           1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2           2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3           3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4           4  2022/6/11 11:42:00   799  Dark Blue         M         264
# ..        ...                 ...   ...        ...       ...         ...
# 522       171    2022/9/9 6:27:00   799  Dark Blue         M         265
# 523       172    2022/9/9 7:18:00   708  Dark Blue       4XL         278
# 524       173    2022/9/9 7:22:00   799  Dark Blue         M         265
# 525       174    2022/9/9 8:25:00   799  Dark Blue         L         265
# 526       175    2022/9/9 9:47:00   799  Dark Blue        XL         265
#
#      quantity  revenue
# 0           1      298
# 1           1      258
# ...

# %%
df.isnull().sum()
# Out:
# order_id       0
# order_date     0
# sku            0
# color          0
# size          37
# unit_price     0
# quantity       0
# revenue        0
# dtype: int64

# %%
df['size'] = df['size'].fillna('XL')
df
# Out:
#      order_id          order_date   sku      color      size  unit_price  \
# 0           1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1           1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2           2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3           3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4           4  2022/6/11 11:42:00   799  Dark Blue         M         264
# ..        ...                 ...   ...        ...       ...         ...
# 522       171    2022/9/9 6:27:00   799  Dark Blue         M         265
# 523       172    2022/9/9 7:18:00   708  Dark Blue       4XL         278
# 524       173    2022/9/9 7:22:00   799  Dark Blue         M         265
# 525       174    2022/9/9 8:25:00   799  Dark Blue         L         265
# 526       175    2022/9/9 9:47:00   799  Dark Blue        XL         265
#
#      quantity  revenue
# 0           1      298
# 1           1      258
# ...

# %%
df.isnull().sum()
# Out:
# order_id      0
# order_date    0
# sku           0
# color         0
# size          0
# unit_price    0
# quantity      0
# revenue       0
# dtype: int64

# %%
df['sku'].unique()
# Out:
# array(['708', '89', 'bobo', '799', '239', '77', '897', '9699', '127',
#        '1719', '439', '3799', '229', '2499', '79', '29', '1499', '628',
#        '61399', '339', '218', '8499', '3081', '539'], dtype=object)

# %%
df.isnull().sum()
# Out:
# order_id      0
# order_date    0
# sku           0
# color         0
# size          0
# unit_price    0
# quantity      0
# revenue       0
# dtype: int64

# %%
df1 = df[df['sku']!='bobo']

# %%
df1
# Out:
#      order_id          order_date  sku      color size  unit_price  quantity  \
# 0           1   2022/6/1 16:05:00  708  Dark Blue  2XL         298         1
# 1           1   2022/6/1 16:05:00   89  Dark Blue  2XL         258         1
# 3           3  2022/6/10 19:59:00  799  Dark Blue   XL         264         1
# 4           4  2022/6/11 11:42:00  799  Dark Blue    M         264         1
# 5           5  2022/6/11 14:46:00  799  Dark Blue   XL         264         1
# ..        ...                 ...  ...        ...  ...         ...       ...
# 522       171    2022/9/9 6:27:00  799  Dark Blue    M         265         1
# 523       172    2022/9/9 7:18:00  708  Dark Blue  4XL         278         1
# 524       173    2022/9/9 7:22:00  799  Dark Blue    M         265         1
# 525       174    2022/9/9 8:25:00  799  Dark Blue    L         265         1
# 526       175    2022/9/9 9:47:00  799  Dark Blue   XL         265         1
#
#      revenue
# 0        298
# 1        258
# ...

# %%
df1.head()
# Out:
#    order_id          order_date  sku      color size  unit_price  quantity  \
# 0         1   2022/6/1 16:05:00  708  Dark Blue  2XL         298         1
# 1         1   2022/6/1 16:05:00   89  Dark Blue  2XL         258         1
# 3         3  2022/6/10 19:59:00  799  Dark Blue   XL         264         1
# 4         4  2022/6/11 11:42:00  799  Dark Blue    M         264         1
# 5         5  2022/6/11 14:46:00  799  Dark Blue   XL         264         1
#
#    revenue
# 0      298
# 1      258
# 3      264
# 4      264
# 5      264

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 511 entries, 0 to 526
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    511 non-null    int64
#  1   order_date  511 non-null    object
#  2   sku         511 non-null    object
#  3   color       511 non-null    object
#  4   size        511 non-null    object
#  5   unit_price  511 non-null    int64
#  6   quantity    511 non-null    int64
#  7   revenue     511 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 35.9+ KB

# %%
df1.tail()
# Out:
#      order_id        order_date  sku      color size  unit_price  quantity  \
# 522       171  2022/9/9 6:27:00  799  Dark Blue    M         265         1
# 523       172  2022/9/9 7:18:00  708  Dark Blue  4XL         278         1
# 524       173  2022/9/9 7:22:00  799  Dark Blue    M         265         1
# 525       174  2022/9/9 8:25:00  799  Dark Blue    L         265         1
# 526       175  2022/9/9 9:47:00  799  Dark Blue   XL         265         1
#
#      revenue
# 522      265
# 523      278
# 524      265
# 525      265
# 526      265

# %%
df.describe()
# Out:
#          order_id  unit_price    quantity     revenue
# count  527.000000  527.000000  527.000000  527.000000
# mean   115.313093  274.973435    1.011385  278.024668
# std     73.106716   34.517412    0.106193   44.741095
# min      1.000000  191.000000    1.000000  191.000000
# 25%     54.000000  266.000000    1.000000  266.000000
# 50%    110.000000  278.000000    1.000000  278.000000
# 75%    166.000000  288.000000    1.000000  288.000000
# max    273.000000  899.000000    2.000000  899.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1['sku'] = df1['sku'].astype(int)
df1
# Out:
# C:\Users\Sruti\AppData\Local\Temp\ipykernel_3328\2512978547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['sku'] = df1['sku'].astype(int)
#      order_id          order_date  sku      color size  unit_price  quantity  \
# 0           1   2022/6/1 16:05:00  708  Dark Blue  2XL         298         1
# 1           1   2022/6/1 16:05:00   89  Dark Blue  2XL         258         1
# 3           3  2022/6/10 19:59:00  799  Dark Blue   XL         264         1
# 4           4  2022/6/11 11:42:00  799  Dark Blue    M         264         1
# 5           5  2022/6/11 14:46:00  799  Dark Blue   XL         264         1
# ..        ...                 ...  ...        ...  ...         ...       ...
# ...

# %%
df.isnull().sum()
# Out:
# order_id      0
# order_date    0
# sku           0
# color         0
# size          0
# unit_price    0
# quantity      0
# revenue       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df['size'].unique()
# Out:
# array(['2XL', 'One Size', 'XL', 'M', '3XL', 'L', '4XL', 'S', 'One SIze'],
#       dtype=object)

# %%
df['size'].value_counts()
# Out:
# size
# XL          201
# M            92
# L            91
# One Size     45
# 2XL          43
# 3XL          40
# 4XL           9
# One SIze      5
# S             1
# Name: count, dtype: int64

# %%
plt.bar(df['size'].unique(),df['size'].value_counts())
plt.xlabel('size')
plt.ylabel('count')
plt.title('size vs count')
plt.show()

# %%
df['size'].unique()
# Out:
# Index(['order_id', 'order_date', 'sku', 'color', 'size', 'unit_price',
#        'quantity', 'revenue'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'sku', 'color', 'size', 'unit_price',
#        'quantity', 'revenue'],
#       dtype='object')

# %%
df.groupby('size')['revenue'].mean()
# Out:
# size
# 2XL         288.883721
# 3XL         282.525000
# 4XL         356.111111
# L           278.703297
# M           279.945652
# One SIze    198.000000
# One Size    262.066667
# S           227.000000
# XL          275.940299
# Name: revenue, dtype: float64

# %%
plt.barh(df['size'].unique(),df.groupby('size')['revenue'].mean(),label=df['size'].unique(),color="r",edgecolor = 'g')
plt.xlabel('size')
plt.ylabel('count')
plt.title('size vs count')
plt.legend()
plt.show()

# %%
x = df1.groupby('size')['sku'].max()

# %%
plt.pie(x = x, labels = df1['size'].unique(),autopct ="%1.1f%%" )
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]

# %%
plt.plot(x,y,marker = "*" , ls="--",c="g")
plt.grid()
plt.show()

# %%
plt.scatter(x,y,s=90,marker="^",edgecolors = "r")

# %%
df.head()
# Out:
#    order_id          order_date   sku      color      size  unit_price  \
# 0         1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1         1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2         2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3         3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4         4  2022/6/11 11:42:00   799  Dark Blue         M         264
#
#    quantity  revenue
# 0         1      298
# 1         1      258
# 2         1      228
# 3         1      264
# 4         1      264

# %%
df['month']=df["order_date"].apply(lambda x : x.split("/")[1])

# %%
df
# Out:
#      order_id          order_date   sku      color      size  unit_price  \
# 0           1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1           1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2           2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3           3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4           4  2022/6/11 11:42:00   799  Dark Blue         M         264
# ..        ...                 ...   ...        ...       ...         ...
# 522       171    2022/9/9 6:27:00   799  Dark Blue         M         265
# 523       172    2022/9/9 7:18:00   708  Dark Blue       4XL         278
# 524       173    2022/9/9 7:22:00   799  Dark Blue         M         265
# 525       174    2022/9/9 8:25:00   799  Dark Blue         L         265
# 526       175    2022/9/9 9:47:00   799  Dark Blue        XL         265
#
#      quantity  revenue month
# 0           1      298     6
# 1           1      258     6
# ...

# %%
plt.stackplot(df['size'].unique(),df.groupby("size")["revenue"].mean(),df.groupby('size')["revenue"].min())

# %%
plt.subplot(1,2,1)
plt.stackplot(df['size'].unique(),df.groupby('size')['revenue'].mean(),df.groupby('size')['revenue'].min())
plt.subplot(1,2,2)
plt.fill_between(x,y)
